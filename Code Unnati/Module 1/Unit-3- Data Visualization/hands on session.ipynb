# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[3,1,2]
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
x=[1,2,3]
y=[1,2,5]
plt.plot(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("My Graph")
plt.show()

# %%
import  numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,10,0.1)
y=np.sin(x)
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
import  numpy as np
import matplotlib.pyplot as plt
x=np.arange(0,10,0.1)
y=np.cos(x)
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
x=np.arange(0,10,0.1)
y=np.tan(x)
plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
#plot1
x=np.array([1,2,3,4])
y=np.array([2,3,4,6])
plt.subplot(2,1,1)
plt.plot(x,y)
#plot2
x=np.array([1,2,3,4])
y=np.array([10,40,20,3])
plt.subplot(2,1,2)
plt.plot(x,y)

# %%
#plot4
x=np.array([1,2,3,4])
y=np.array([2,3,4,6])
plt.subplot(2,2,2)
plt.plot(x,y)
#plot5
x=np.array([1,2,3,4])
y=np.array([10,40,20,3])
plt.subplot(2,2,3)
plt.plot(x,y)
#plot6
x=np.array([1,2,3,4])
y=np.array([10,4,2,3])
plt.subplot(2,2,1)
plt.plot(x,y)

# %%
#subplots
#plot1
x=np.array([1,2,3,4])
y=np.array([2,3,4,6])
plt.subplot(1,6,1)
plt.plot(x,y)
#plot2
x=np.array([1,2,3,4])
y=np.array([10,40,20,3])
plt.subplot(1,6,3)
plt.plot(x,y)
#plot3
x=np.array([1,2,3,4])
y=np.array([10,4,2,3])
plt.subplot(1,6,5)
plt.plot(x,y)
# plot 4
x=np.array([1,2,5,4])
y=np.array([10,1,2,3])
plt.subplot(1,7,7)
plt.plot(x,y)

# %%
#marker
ypoints=np.array([3,8,1,4])
plt.plot(ypoints,marker='o')
plt.show()

ypoints=np.array([3,2,1,4])
plt.plot(ypoints,marker='s')
plt.show()

ypoints=np.array([2,8,1,4])
plt.plot(ypoints,marker='p')
plt.show()

ypoints=np.array([3,7,1,4])
plt.plot(ypoints,marker='P')
plt.show()

ypoints=np.array([3,9,1,4])
plt.plot(ypoints,marker='*')
plt.show()

ypoints=np.array([3,8,1,6])
plt.plot(ypoints,marker='v')
plt.show()

# %%
#linestyle
ypoints=np.array([3,8,1,4])
plt.plot(ypoints,linestyle= 'dotted')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,linestyle= 'dashed')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,linestyle= 'dashdot')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,linestyle= 'solid')
plt.show()

# %%
#color
ypoints=np.array([3,8,1,4])
plt.plot(ypoints,color='r')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,color='b')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,color='g')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,color='grey')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,color='violet')
plt.show()

# %%
#markersize
ypoints=np.array([3,8,1,4])
plt.plot(ypoints,marker='p', ms ='2',mec='r')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,linestyle='dotted',marker='v', ms ='20', mec='b')
plt.show()

ypoints=np.array([3,8,1,4])
plt.plot(ypoints,linestyle='dashed',marker='*', ms ='23', mec='violet')
plt.show()

# %%
#bar
import matplotlib.pyplot as plt
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#scatter
x=[5,2,9,4,7,4,3]
y=[10,5,8,4,2,4,1]
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ticks
x=[5,10,15,20,25,30,35,40]
y=[1,2,3,4,5,6,7,8]
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis="x",labelsize=18,labelrotation=-60,labelcolor='blue')
plt.tick_params(axis="y",labelsize=12,labelrotation=20,labelcolor='black')

# %%
x=[5,10,15,20,25,30,35,40]
y=[1,2,3,4,5,6,7,8]
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.tick_params(axis="x",labelsize=18,labelrotation=-60,labelcolor='blue')
plt.tick_params(axis="x",labelsize=12,labelrotation=20,labelcolor='black')

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.bar(x,y)
plt.title("Bar Graph")
plt.xlabel("Time(hr)")
plt.ylabel("Position(km)")
plt.show()

# %%
#legend
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.plot(x)
plt.plot(y)
plt.legend(["blue",'green'],loc="lower right")
plt.show()

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.plot(x)
plt.plot(y)
plt.legend(["blue",'green'],loc="right")
plt.show()

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.plot(x)
plt.plot(y)
plt.legend(["blue",'green'],loc="lower left")
plt.show()

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.plot(x)
plt.plot(y)
plt.legend(["blue",'green'],loc="left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 5>()
#       3 plt.plot(x)
#       4 plt.plot(y)
# ----> 5 plt.legend(["blue",'green'],loc="left")
#       6 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2655, in legend(*args, **kwargs)
#    2653 @_copy_docstring_and_deprecators(Axes.legend)
#    2654 def legend(*args, **kwargs):
# -> 2655     return gca().legend(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:305, in Axes.legend(self, *args, **kwargs)
#     303 if len(extra_args):
#     304     raise TypeError('legend only accepts two non-keyword arguments')
# --> 305 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     306 self.legend_._remove_method = self._remove_legend
#     307 return self.legend_
#
# ...

# %%
x=[5,2,9,4,7]
y=[10,5,8,4,2]
plt.plot(x)
plt.plot(y)
plt.legend(["blue",'green'],loc="best")
plt.show()

# %%
#histogram
import numpy as np
data=np.random.normal(170,10,250)
plt.hist(data)
print(data)
plt.show()
plt.hist(data,bins=30)
plt.show()
plt.hist(data,bins=50)
plt.show()
plt.hist(data,bins=10)
plt.show()
plt.hist(data,bins=100)
plt.show()
# Out:
# [175.99647256 156.15142813 175.39346935 169.00353528 178.53730722
#  180.3256848  166.4147948  169.93117273 157.61911631 173.61628395
#  151.09351371 165.72676313 171.8668472  155.94490334 174.55405632
#  166.14862219 160.13867951 168.8886786  170.21324043 186.06182344
#  169.35760758 152.01093472 173.69725055 178.12656615 183.50694715
#  163.72142717 166.6292845  167.46917632 167.22306844 167.10160713
#  150.1032862  158.28515151 176.89036335 174.62915579 173.85723721
#  194.40003377 155.67086156 199.25571317 175.7668344  183.28776333
#  181.88553105 168.69616284 161.01522288 174.46458119 185.88122958
#  184.45618045 178.76399568 178.77697647 172.76346381 157.19996696
#  174.71030657 171.14552948 160.62380358 166.1888957  170.14768294
#  165.47902613 169.2122785  172.15362141 159.65983662 165.11733128
#  172.68568153 160.41115873 168.23404362 171.97173071 164.30075858
#  167.29049346 175.00324493 155.90196816 185.95392299 180.01293874
# ...

# %%
#annotation
fig,ax=plt.subplots()
x=np.linspace(0,20,1000)
ax.plot(x,np.cos(x))
ax.axis('equal')
ax.annotate('local maximum',xy=(6.28,1),xytext=(10,4),arrowprops=dict(facecolor='black',shrink=0.05))
ax.annotate('local minimum',xy=(5*np.pi,-1),xytext=(2,-6),arrowprops=dict(arrowstyle="->",connectionstyle="angle3,angleA=0,angleB=-90"))
# Out:
# Text(2, -6, 'local minimum')

# %%
w=4
h=3
d=70
plt.figure(figsize=(w,h),dpi=d)
plt.axis([0,5,0,5])
x=[0,3,5]
y=[1,4,3.5]
label_x=1
label_y=4
arrow_x=3
arrow_y=4
arrow_properties=dict(facecolor="black",width=0.5,headwidth=4,shrink=0.1)
plt.annotate("maximum",xy=(arrow_x,arrow_y),xytext=(label_x,label_y),arrowprops=arrow_properties)
plt.plot(x,y)
plt.show(x,y)

# %%
w=9
h=10
d=90
plt.figure(figsize=(w,h),dpi=d)
plt.axis([0,5,0,5])
x=[0,3,5]
y=[1,4,3.5]
label_x=1
label_y=4
arrow_x=3
arrow_y=4
arrow_properties=dict(facecolor="black",width=0.5,headwidth=4,shrink=0.1)
plt.annotate("maximum",xy=(arrow_x,arrow_y),xytext=(label_x,label_y),arrowprops=arrow_properties)
plt.plot(x,y)
plt.show(x,y)

# %%
#3Dplot
from mpl_toolkits import mplot3d
fig= plt.figure()
ax=plt.axes(projection='3d')
z=np.linspace(0,1,100)
x=z*np.sin(25*z)
y=z*np.cos(25*z)
ax.plot3D(x,y,z,"green")
ax.set_title("3D line plot")
plt.show()

# %%
#piechart
cars=["AUDI","BMW","FORD",'TESLA','JAGUAR','MERCEDES']
data=[23,17,35,29,12,41]
fig=plt.figure(figsize=(10,7))
plt.pie(data,labels=cars)
plt.show()
